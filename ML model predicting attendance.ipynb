# %% [markdown]
# # Python Assignment: ML Model for Predicting Attendance

# %% [markdown]
# ## **Overview**
# 1. [Data Collection](#0)
# 2. [Exploratory Data Analysis](#1)
# 3. [Data Preprocessing](#2)
#     3.1. [Remove Outliers](#3)
#     3.2. [Remove Redundant](#4)
#     3.3. [Replace Null Values](#5)
# 4. [Feature Engineering](#6)
#     4.1. [Feature Creation](#7)
#     4.2. [Encoding](#8)
#     4.3. [Feature Importance](#9)
# 5. [Modelling](#10)
#     5.1. [Train Test Split](#11)
#     5.2. [Scaling](#12)
#     5.2. [Selection](#13)
# 6. [Prediction](#14)

# %% [markdown]
# <a id='0'></a>
# ## 1. Data Collection

# %%
# Import all required libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.offline as py
import plotly.express as px
import my_lib # This is our library with all functions we created
pd.options.display.max_columns = None
py.init_notebook_mode(connected=True) # this allows to display plotly graphs in Jupyter
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Import the data sets
construction_df = pd.read_csv("./construction_dataset.csv")
production_df = pd.read_csv("./production_dataset.csv")

# %% [markdown]
# <a id='1'></a>
# ## 2. Exploratory Data Analysis

# %%
construction_df.head()
# Out:
#    Unnamed: 0  year          home_team month  day  attend day_of_week  \
# 0           0  2012  Baltimore Orioles   APR    6   32741      Friday
# 1           1  2012  Baltimore Orioles   APR    7   22072    Saturday
# 2           2  2012  Baltimore Orioles   APR    8   10317      Sunday
# 3           3  2012  Baltimore Orioles   APR    9   17835      Monday
# 4           4  2012  Baltimore Orioles   APR   10   17261     Tuesday
#
#            opponent  temp   skies day_night cap shirt fireworks bobblehead  \
# 0   Minnesota Twins    59   Clear       Day  NO    NO        NO         NO
# 1   Minnesota Twins    63   Clear     Night  NO    NO        NO         NO
# 2   Minnesota Twins    68   Clear       Day  NO    NO        NO         NO
# 3  New York Yankees    65  Cloudy     Night  NO    NO        NO         NO
# 4  New York Yankees    62   Clear     Night  NO    NO        NO         NO
#
#   hum>average  attend_inc  attend_thousands
# 0          NO         NaN                33
# 1         YES    -10669.0                22
# 2         YES    -11755.0                10
# 3          NO      7518.0                18
# 4          NO      -574.0                17

# %%
construction_df.dtypes
# Out:
# Unnamed: 0            int64
# year                  int64
# home_team            object
# month                object
# day                   int64
# attend                int64
# day_of_week          object
# opponent             object
# temp                  int64
# skies                object
# day_night            object
# cap                  object
# shirt                object
# fireworks            object
# bobblehead           object
# hum>average          object
# attend_inc          float64
# attend_thousands      int64
# dtype: object

# %%
print(construction_df[["year","month"]].value_counts())
# Out:
# year  month
# 2012  AUG      424
#       MAY      424
#       JUN      404
#       JUL      383
#       APR      334
#       SEP      212
# dtype: int64

# %% [markdown]
# Observation:
# - The year is a constant across all datasets and can be disregarded.
# - June - August months are not represented in the test set, only September is present in both datasets.

# %% [markdown]
# ### 2.1. Distributions & Correlations

# %%
fig = px.histogram(construction_df, x="attend", marginal = "box")
fig.update_layout(title = "Distribution of Attendance (Target Variable)",width=800,height= 600)
fig.show()
# Out:
# <div>                            <div id="3e525a43-c7a2-4d2d-a765-bea70a2997ae" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e525a43-c7a2-4d2d-a765-bea70a2997ae")) {                    Plotly.newPlot(                        "3e525a43-c7a2-4d2d-a765-bea70a2997ae",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"attend=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[32741,22072,10317,17835,17261,16043,7741,7290,9608,12808,18848,22255,8357,7884,13475,18668,23003,20686,11544,16838,11474,17620,19464,20268,18700,23743,28321,32628,31687,10933,16267,20996,32124,32409,29256,17007,12638,12373,17345,24734,11682,24896,30250,21307,12314,13707,14911,20495,14800,13789,14829,10803,12118,14858,12094,28319,14654,18343,15588,17838,18028,17557,7668,8989,9169,7099,32409,28603,32247,28242,16680,25922,26617,26617,26676,26760,26577,25739,26487,26151,26058,26204,26056,26307,26176,26144,26207,26634,26328,26134,26104,26316,26669,26491,26545,26051,26036,26340,26027,26070,26115,26116,26274,26227,26391,26153,26083,26097,26447,26296,26046,26428,26421,26646,26719,26454,26789,26834,26440,26157,26889,26665,26719,26416,26449,26092,26049,26034,26100,26540,25913,26121,26891,26401,26456,26161,26480,26060,25972,26032,26254,26009,25975,26058,27073,23118,17600,9612,7887,9673,8285,14186,14290,14040,15968,10648,10634,12120,13390,14046,15845,16477,15031,14018,14045,14117,14960,19006,15527,13418,18340,16143,16175,17970,18020,15716,16016,14279,23250,21197,22618,15959,21236,18582,21128,21190,14902,18990,17779,19033,26452,24300,22583,22442,20000,21141,21068,19036,17606,17529,18680,17574,19293,16973,18423,17541,19293,16202,15173,10989,12135,18662,18359,13549,21201,18553,21467,30233,13189,7363,6631,6350,6396,7386,6460,8818,7921,10795,11303,14915,12720,6437,7338,7913,7899,8464,9026,20565,20859,16568,10534,15400,16535,17764,9977,11978,13933,17828,14867,22344,21286,19172,13964,12049,16481,15131,20504,14685,18604,20114,14461,13414,23768,25373,19634,12785,16546,16820,24205,13142,10369,13164,13747,19072,19526,19242,19590,24062,18316,9113,9389,10088,10150,11690,12053,13632,12030,15994,12063,7239,31519,31297,21552,15802,19726,21202,21020,28999,24501,25378,21051,19969,22016,21111,23231,23530,29683,27691,23768,26488,29163,30067,27980,29282,31215,29693,23281,21945,28596,29315,29260,28433,25713,27210,28543,26184,25730,28716,23345,27401,27574,25685,25764,23734,26540,28218,31200,30022,28897,29051,29921,26605,28967,27832,29315,28658,29134,29492,28358,27649,26058,27937,27549,29379,28052,25705,28041,29534,24793,19410,20217,21870,20814,30425,16773,9936,11966,15425,12758,21189,17893,16764,12275,12571,13609,19041,16543,15602,11572,10361,11250,10817,10621,24300,29871,25111,11826,14064,13112,15025,16094,13940,13238,12962,15585,10805,12669,21481,18852,23969,14834,10138,10791,10508,13590,16401,16119,11876,10877,11136,11254,13948,17280,23902,14317,9690,9991,11227,10092,14717,12559,13464,13456,14587,10446,9461,9245,8984,10701,12821,12104,9185,9944,9171,9120,12274,28161,15252,14827,9827,9696,9858,16145,19463,18824,9287,13713,16907,20385,14304,13651,14367,12837,12564,21753,23586,19228,16964,20669,18393,14778,11572,16754,12870,16981,12520,15308,26531,26068,20344,14140,18187,13460,22921,17499,18000,11688,11038,12118,11694,18003,18723,16276,12998,11923,10594,18822,20107,15405,11275,10914,10042,15518,16701,15681,9521,9117,9098,16232,16549,15545,8723,9348,10732,19310,16119,17485,10094,30874,28015,22559,19137,28711,19052,19505,22590,26638,26755,18919,21027,19102,19851,23212,27313,26284,22996,22233,27319,21550,30811,29445,28078,28056,30959,29725,25255,24515,26139,25967,29738,29555,28864,26607,28225,31184,31158,30782 ...

# %%
fig = px.histogram(construction_df, x="temp", marginal = "box")
fig.update_layout(title = "Distribution of Temperature", width=800,height= 600)
fig.show()
# Out:
# <div>                            <div id="f1a22506-f352-4ba9-8ad7-8466bc14f9ce" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1a22506-f352-4ba9-8ad7-8466bc14f9ce")) {                    Plotly.newPlot(                        "f1a22506-f352-4ba9-8ad7-8466bc14f9ce",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"temp=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[59,63,68,65,62,53,60,70,64,60,56,64,67,68,61,71,77,79,66,78,72,76,75,82,87,86,81,86,90,72,76,79,76,87,88,78,85,92,100,91,95,85,86,87,86,85,84,88,88,81,88,85,85,84,86,73,81,84,80,84,84,77,87,86,82,81,80,83,67,74,75,58,72,72,79,78,51,79,78,52,46,47,53,56,54,60,64,77,74,57,70,73,83,70,69,68,75,76,55,58,59,67,78,76,74,96,92,74,65,82,72,69,75,81,85,86,87,79,89,73,75,69,72,84,79,68,75,84,88,79,89,79,75,85,79,74,84,74,73,76,84,77,77,67,64,63,73,53,51,68,50,39,39,46,47,56,76,82,74,54,58,70,83,62,72,82,66,73,93,57,73,75,58,66,72,83,87,89,88,88,86,75,75,89,93,97,99,91,75,75,90,75,92,80,72,82,82,86,73,68,70,75,71,73,76,84,86,73,79,76,85,63,70,65,72,77,82,44,48,51,56,45,6,55,58,48,43,52,66,58,59,61,57,63,56,59,60,66,71,74,61,65,81,90,76,70,60,71,73,72,78,78,74,84,88,83,85,92,83,88,90,79,71,79,82,91,78,82,73,77,81,83,73,73,68,72,79,82,83,75,75,71,73,81,76,76,63,68,72,59,43,62,58,42,46,54,62,43,50,48,60,61,58,55,71,64,66,65,64,59,73,83,82,56,71,77,66,77,79,83,86,79,92,92,92,88,79,78,79,94,91,81,93,100,83,69,80,84,84,91,89,82,80,87,87,64,76,72,73,68,78,81,85,88,81,94,80,78,81,79,78,56,64,79,80,72,79,78,81,73,73,75,80,80,72,84,87,72,72,72,81,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,83,73,73,73,73,66,72,72,64,69,76,59,68,58,65,83,85,87,72,71,73,69,77,81,84,85,72,63,76,69,90,83,81,81,86,87,85,77,96,89,93,97,88,97,94,95,98,103,98,93,99,98,100,99,94,93,91,87,72,93,73,82,81,80,94,96,97,77,86,90,92,91,90,68,70,70,68,69,85,80,71,72,68,67,63,64,65,64,60,63,66,67,68,71,70,74,76,73,74,72,68,66,66,70,65,71,74,65,69,76,71,69,68,71,76,78,69,73,75,79,81,82,77,77,73,75,73,80,78,85,84,91,82,86,76,83,84,84,92,86,79,80,81,80,91,78,73,76,85,79,45,50,56,49,65,62,62,71,71,53,55,65,52,65,73,51,69,71,84,72,66,61,85,74,62,58,89,86,88,68,76,67,78,74,79,76,81,83,88,85,91,91,68,90,89,97,90,76,75,77,82,72,85,77,81,76,77,68,80,75,72,84,83,91,85,64,70,71,80,93,58,73,74,59,68,74,77,73,58,60,47,58,57,52,66,53,61,66,61,68,77,79,66,74,72,61,67,71,62,68,70,77,75,81,67,72,94,64,72,78,88,95,93,95,81,85,87,89,95,94,86,69,76,77,76,80,84,91,89,84,78,71,82,78,78,72,78,83,76,87,88,80,71,72,72,67,55,59,55,55,59,67,75,64,60,62,63,65,63,70,65,66,64,59,63,65,59,59,56,58,62,61,64,67,85,68,67,65,55,61,63,65,63,65,66,66,66,61,63,63,65,70,72,70,72,65,65,63,61,62,63,67,67,70,63,65,63,61,62,63,59,63,71,73,61,61,62,57,60,52,50,55,55,54,64,61,50,56,56,67,57,49,60,56,55,59,69,73,60,57,61,59,66,57,57,66,67,64,62,60,61,69,71,64,62,61,59,61,67,82,65,65,68,67,74,66,64,65,67,70,70,75,75,79,79,67,68,73,67,62,66,59,60,65,71,69,75,75,64,69,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,72,75,82,65,75,82,81,77,75,86,88,88,87,85,73,69,80,80,83,87,86,90,91,88,93,90,90,81,86,93,86,91,90,95,95,97,100,103,99,97,96,96,83,98,83,96,97,94,98,95,100,104,102,103,105,102,96,96,100,88,75,89,92,92,91,87,91,89,95,88,92,83,66,72,68,68,68,68,68,68,68,68,61,68,68,68,68,68,53,64,73,68,63,59,63,79,73,80,68,68,68,68,68,77,66,70,75,68,73,88,77,77,77,68,91,75,79,79,68,79,68,68,75,77,75,68,68,68,73,70,73 ...

# %% [markdown]
# To smooth our dataset, we will remove the outlier having low temperature, as it represents only one row.

# %% [markdown]
# #### Relationship of Home team with attendance

# %%
construction_df = construction_df.sort_values('attend')
# Plot Neighborhoods against their distribution of housing price using box plot
fig = px.box(construction_df,y="attend",  x="home_team"
            , color_discrete_sequence=["orange"], orientation = 'v')

fig.update_layout(title = "Distribution of attendance by home_teams")
fig.show()
# Out:
# <div>                            <div id="9c03b480-e354-4dd3-86fa-de7a710cb101" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c03b480-e354-4dd3-86fa-de7a710cb101")) {                    Plotly.newPlot(                        "9c03b480-e354-4dd3-86fa-de7a710cb101",                        [{"alignmentgroup":"True","hovertemplate":"home_team=%{x}<br>attend=%{y}<extra></extra>","legendgroup":"","marker":{"color":"orange"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Cleveland Indians","Cleveland Indians","Cleveland Indians","Cleveland Indians","Tampa Bay Rays","Cleveland Indians","Tampa Bay Rays","Tampa Bay Rays","Tampa Bay Rays","Oakland Athletics","Oakland Athletics","Baltimore Orioles","Oakland Athletics","Pittsburgh Pirates","Cleveland Indians","Baltimore Orioles","Cleveland Indians","Pittsburgh Pirates","Cleveland Indians","Cleveland Indians","Oakland Athletics","Oakland Athletics","Oakland Athletics","Oakland Athletics","Oakland Athletics","Tampa Bay Rays","Tampa Bay Rays","Baltimore Orioles","Baltimore Orioles","Oakland Athletics","Baltimore Orioles","Chicago White Sox","Cleveland Indians","Oakland Athletics","Cleveland Indians","Cleveland Indians","Seattle Mariners","Tampa Bay Rays","Pittsburgh Pirates","Tampa Bay Rays","Oakland Athletics","Tampa Bay Rays","Tampa Bay Rays","Oakland Athletics","Tampa Bay Rays","Chicago White Sox","Oakland Athletics","Tampa Bay Rays","Baltimore Orioles","Pittsburgh Pirates","Cleveland Indians","Tampa Bay Rays","Oakland Athletics","Seattle Mariners","Kansas City Royals","Seattle Mariners","Oakland Athletics","Cleveland Indians","Seattle Mariners","Pittsburgh Pirates","Houston Astros","Baltimore Orioles","Cleveland Indians","Oakland Athletics","Toronto Blue Jays","Seattle Mariners","Kansas City Royals","Cleveland Indians","Kansas City Royals","Houston Astros","Oakland Athletics","Seattle Mariners","Seattle Mariners","Seattle Mariners","Baltimore Orioles","Houston Astros","Oakland Athletics","Houston Astros","Houston Astros","Kansas City Royals","Oakland Athletics","Kansas City Royals","Tampa Bay Rays","Cleveland Indians","Tampa Bay Rays","Seattle Mariners","Houston Astros","Toronto Blue Jays","Toronto Blue Jays","Kansas City Royals","Baltimore Orioles","Chicago White Sox","Tampa Bay Rays","Toronto Blue Jays","Chicago White Sox","Tampa Bay Rays","Houston Astros","Kansas City Royals","Seattle Mariners","Oakland Athletics","Kansas City Royals","Kansas City Royals","Tampa Bay Rays","Pittsburgh Pirates","Houston Astros","Houston Astros","Cleveland Indians","Houston Astros","Tampa Bay Rays","Oakland Athletics","Kansas City Royals","Seattle Mariners","Cleveland Indians","Houston Astros","Kansas City Royals","Toronto Blue Jays","Seattle Mariners","Houston Astros","Cleveland Indians","Washington Nationals","Pittsburgh Pirates","Tampa Bay Rays","Seattle Mariners","Baltimore Orioles","Oakland Athletics","Pittsburgh Pirates","Houston Astros","Seattle Mariners","Cleveland Indians","Oakland Athletics","Houston Astros","Tampa Bay Rays","Seattle Mariners","Houston Astros","Seattle Mariners","Oakland Athletics","Cleveland Indians","Oakland Athletics","Kansas City Royals","Tampa Bay Rays","San Diego Padres","Houston Astros","Chicago White Sox","Chicago White Sox","Pittsburgh Pirates","Houston Astros","Toronto Blue Jays","Toronto Blue Jays","Kansas City Royals","Pittsburgh Pirates","Oakland Athletics","Houston Astros","Tampa Bay Rays","Cleveland Indians","Baltimore Orioles","Houston Astros","Houston Astros","Oakland Athletics","Pittsburgh Pirates","Toronto Blue Jays","Houston Astros","Kansas City Royals","Seattle Mariners","Toronto Blue Jays","Baltimore Orioles","Seattle Mariners","Chicago White Sox","Tampa Bay Rays","Kansas City Roya ...

# %% [markdown]
# Observation: The feature "home_team" is highly correlated with the attendance, we can include its impact during feature engineering

# %% [markdown]
# #### Relationship of Opponent team with attendance

# %%
construction_df = construction_df.sort_values('attend')
# Plot Neighborhoods against their distribution of housing price using box plot
fig = px.box(construction_df,y="attend",  x="opponent"
            , color_discrete_sequence=["orange"], orientation = 'v')

fig.update_layout(title = "Distribution of attendance by opponent")
fig.show()
# Out:
# <div>                            <div id="c1b47912-5fe1-47aa-9026-f04ae8f9e451" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c1b47912-5fe1-47aa-9026-f04ae8f9e451")) {                    Plotly.newPlot(                        "c1b47912-5fe1-47aa-9026-f04ae8f9e451",                        [{"alignmentgroup":"True","hovertemplate":"opponent=%{x}<br>attend=%{y}<extra></extra>","legendgroup":"","marker":{"color":"orange"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Chicago White Sox","Kansas City Royals","Chicago White Sox","Kansas City Royals","Seattle Mariners","Chicago White Sox","Seattle Mariners","Kansas City Royals","Seattle Mariners","Kansas City Royals","Texas Rangers","Chicago White Sox","Minnesota Twins","Washington Nationals","Minnesota Twins","Toronto Blue Jays","Chicago White Sox","Colorado Rockies","Toronto Blue Jays","Kansas City Royals","Chicago White Sox","Kansas City Royals","Toronto Blue Jays","Seattle Mariners","Toronto Blue Jays","Toronto Blue Jays","Kansas City Royals","Chicago White Sox","Toronto Blue Jays","Chicago White Sox","Texas Rangers","Baltimore Orioles","Chicago White Sox","Los Angeles Angels","Chicago White Sox","Los Angeles Angels","Cleveland Indians","Toronto Blue Jays","Washington Nationals","Boston Red Sox","Detroit Tigers","Seattle Mariners","Oakland Athletics","Los Angeles Angels","Boston Red Sox","Baltimore Orioles","Texas Rangers","Kansas City Royals","Texas Rangers","Cincinnati Reds","Seattle Mariners","Toronto Blue Jays","Kansas City Royals","Oakland Athletics","Texas Rangers","Cleveland Indians","Tampa Bay Rays","Los Angeles Angels","Boston Red Sox","Houston Astros","San Francisco Giants","Chicago White Sox","Seattle Mariners","Los Angeles Angels","Seattle Mariners","Cleveland Indians","Detroit Tigers","Oakland Athletics","Detroit Tigers","Philadelphia Phillies","Chicago White Sox","Baltimore Orioles","Boston Red Sox","San Diego Padres","Chicago White Sox","Chicago Cubs","Minnesota Twins","Chicago Cubs","San Francisco Giants","Toronto Blue Jays","Los Angeles Angels","Texas Rangers","Chicago White Sox","Oakland Athletics","Toronto Blue Jays","Detroit Tigers","San Francisco Giants","Seattle Mariners","Baltimore Orioles","Detroit Tigers","Toronto Blue Jays","Baltimore Orioles","Chicago White Sox","Seattle Mariners","Baltimore Orioles","Toronto Blue Jays","Washington Nationals","Detroit Tigers","San Diego Padres","Cleveland Indians","Detroit Tigers","Detroit Tigers","Seattle Mariners","Houston Astros","Colorado Rockies","Chicago Cubs","Kansas City Royals","Washington Nationals","Cleveland Indians","Cleveland Indians","Oakland Athletics","Oakland Athletics","Oakland Athletics","Washington Nationals","Chicago White Sox","Baltimore Orioles","Detroit Tigers","San Diego Padres","Oakland Athletics","Houston Astros","New York Mets","Los Angeles Angels","Cleveland Indians","Minnesota Twins","Texas Rangers","Cincinnati Reds","Miami Marlins","Baltimore Orioles","Minnesota Twins","Toronto Blue Jays","Arizona Diamondbacks","Los Angeles Angels","Kansas City Royals","San Diego Padres","Kansas City Royals","Texas Rangers","Detroit Tigers","Texas Rangers","Cleveland Indians","Cleveland Indians","Washington Nationals","Milwaukee Brewers","Cleveland Indians","Cleveland Indians","Colorado Rockies","Cincinnati Reds","Tampa Bay Rays","Tampa Bay Rays","Texas Rangers","Washington Nationals","Los Angeles Angels","San Diego Padres","Los Angeles Angels","Los Angeles Angels","Seattle Mariners","Kansas City Royals","Milwaukee Brewers","Los Angeles Angels","Milwaukee Brewers","Kansas City Royals","Cincinnati Reds","Oakland Athletics","Texas Rangers","Tampa Bay Rays","Pittsburgh Pirates","Detroit Tigers","Minnesota Twins","Cleveland Indians"," ...

# %% [markdown]
# Observation: The feature "opponent" is not as correlated with the attendance, but we choose to include its impact during feature engineering to see if the model can be improved.

# %% [markdown]
# #### Relationship of day_of_week with attendance

# %%
construction_df = construction_df.sort_values('attend')
# Plot Neighborhoods against their distribution of housing price using box plot
fig = px.box(construction_df,y="attend",  x="day_of_week"
            , color_discrete_sequence=["orange"], orientation = 'v')

fig.update_layout(title = "Distribution of attendance by day_of_week")
fig.show()
# Out:
# <div>                            <div id="8ccd2114-89e8-4411-a11e-0bd61c0febae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ccd2114-89e8-4411-a11e-0bd61c0febae")) {                    Plotly.newPlot(                        "8ccd2114-89e8-4411-a11e-0bd61c0febae",                        [{"alignmentgroup":"True","hovertemplate":"day_of_week=%{x}<br>attend=%{y}<extra></extra>","legendgroup":"","marker":{"color":"orange"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Wednesday","Tuesday","Monday","Thursday","Monday","Monday","Wednesday","Monday","Tuesday","Monday","Monday","Thursday","Monday","Tuesday","Tuesday","Wednesday","Monday","Tuesday","Sunday","Wednesday","Monday","Tuesday","Tuesday","Friday","Thursday","Monday","Tuesday","Monday","Tuesday","Tuesday","Tuesday","Tuesday","Wednesday","Monday","Tuesday","Saturday","Wednesday","Wednesday","Wednesday","Tuesday","Thursday","Thursday","Thursday","Tuesday","Monday","Thursday","Tuesday","Wednesday","Monday","Tuesday","Wednesday","Tuesday","Wednesday","Tuesday","Tuesday","Tuesday","Monday","Friday","Tuesday","Tuesday","Thursday","Tuesday","Thursday","Tuesday","Tuesday","Thursday","Thursday","Monday","Wednesday","Thursday","Wednesday","Monday","Wednesday","Tuesday","Wednesday","Wednesday","Tuesday","Monday","Wednesday","Monday","Monday","Wednesday","Wednesday","Tuesday","Wednesday","Tuesday","Tuesday","Wednesday","Tuesday","Tuesday","Thursday","Monday","Tuesday","Thursday","Wednesday","Tuesday","Monday","Tuesday","Wednesday","Friday","Monday","Wednesday","Friday","Wednesday","Sunday","Tuesday","Tuesday","Tuesday","Monday","Friday","Thursday","Sunday","Wednesday","Thursday","Tuesday","Wednesday","Monday","Monday","Thursday","Wednesday","Monday","Wednesday","Monday","Sunday","Thursday","Monday","Tuesday","Monday","Tuesday","Wednesday","Sunday","Tuesday","Friday","Wednesday","Thursday","Wednesday","Tuesday","Tuesday","Thursday","Wednesday","Wednesday","Thursday","Wednesday","Tuesday","Wednesday","Friday","Monday","Tuesday","Thursday","Thursday","Wednesday","Tuesday","Thursday","Sunday","Tuesday","Monday","Wednesday","Tuesday","Tuesday","Tuesday","Monday","Wednesday","Tuesday","Tuesday","Tuesday","Wednesday","Tuesday","Tuesday","Tuesday","Wednesday","Tuesday","Wednesday","Tuesday","Monday","Tuesday","Wednesday","Wednesday","Wednesday","Wednesday","Tuesday","Saturday","Friday","Monday","Monday","Monday","Monday","Tuesday","Wednesday","Wednesday","Monday","Tuesday","Wednesday","Monday","Monday","Monday","Monday","Monday","Tuesday","Saturday","Wednesday","Tuesday","Sunday","Monday","Friday","Monday","Thursday","Wednesday","Wednesday","Wednesday","Monday","Wednesday","Wednesday","Wednesday","Monday","Monday","Sunday","Wednesday","Tuesday","Monday","Monday","Tuesday","Wednesday","Wednesday","Saturday","Monday","Friday","Saturday","Sunday","Monday","Friday","Tuesday","Saturday","Monday","Friday","Sunday","Wednesday","Friday","Sunday","Thursday","Wednesday","Wednesday","Thursday","Thursday","Tuesday","Wednesday","Tuesday","Monday","Monday","Tuesday","Tuesday","Tuesday","Friday","Monday","Thursday","Tuesday","Monday","Tuesday","Tuesday","Thursday","Monday","Friday","Wednesday","Tuesday","Wednesday","Wednesday","Tuesday","Wednesday","Saturday","Wednesday","Tuesday","Monday","Thursday","Thursday","Wednesday","Monday","Tuesday","Thursday","Wednesday","Wednesday","Wednesday","Sunday","Saturday","Wednesday","Monday","Monday","Friday","Sunday","Saturday","Wednesday","Thursday","Wednesday","Friday","Wednesday","Friday","Wednesday","Wednesday","Monday","Wednesday","Sunday","Tuesday","Wednesday","Tuesday","Monday","Saturday","Thursday","Tuesday","Wednesday","Friday","Monday","Tuesday","Sunday","Friday","Saturday","Wednesday", ...

# %% [markdown]
# Observation: We can see that for the weekend days (Friday, Saturday, Sunday) the attendance is slightly higher than for the weekdays. We will include this impact in our model by adding a weekend column.

# %% [markdown]
# ### 2.1. Null Values

# %%
# show the % of missing value rows for each column
null_counts = round(100*construction_df.isnull().mean(),2)

# filter out the rows without any missing values and sort in descending order, convert to dataframe
null_counts = pd.DataFrame(data = null_counts[null_counts>0].sort_values(ascending = False), columns = ['%'])

# Create column to show the sum of the rows having missing values for each column
null_counts['# Rows'] = construction_df.isnull().sum()
# Create column to show the datatype of each column
null_counts['DataType'] = construction_df.dtypes

null_counts
# Out:
#                 %  # Rows DataType
# hum>average  4.95     108   object
# attend_inc   1.38      30  float64

# %% [markdown]
# <a id='2'></a>
# ## 3. Data Preprocessing

# %% [markdown]
# <a id='3'></a>
# ### 3.1. Remove Outliers:
# To smooth our dataset, we will remove the outlier having low temperatures that are below 37 degrees, as it represents only one row.

# %%
construction_df = construction_df[construction_df["temp"]> 37]
production_df = production_df[production_df["temp"]> 37]

# %% [markdown]
# <a id='4'></a>
# ### 3.2. Remove Redundant columns:
# - "year": We have seen that year is a constant column showing 2012.
# - "Attend_inc" & "attend_thousands": These columns show the same information as "attend" and are not required further.
# - "Unnamed: 0": This is an index column and unique for each row.

# %%
#Define columns to delete
delete_columns = ["year","attend_inc","attend_thousands","Unnamed: 0"]
# Drop from both construction & production dataset
construction_df = construction_df.drop(delete_columns, axis = 1)
production_df_updated = production_df.drop(delete_columns, axis = 1)

# %% [markdown]
# <a id='5'></a>
# ### 3.3. Replace Null Values:
# "hum>average": This column is a YES/NO categorical column, indicating whether the humidity is above average or not.
# For null values, we assume that the humidity is not above average and replace it with "NO".

# %%
construction_df["hum>average"] = construction_df["hum>average"].fillna("NO")
production_df_updated["hum>average"] = production_df_updated["hum>average"].fillna("NO")

# %% [markdown]
# <a id='6'></a>
# ## 4. Feature Engineering

# %% [markdown]
# <a id='7'></a>
# ### 4.1. Feature Creation

# %% [markdown]
# #### 4.1.1. September:
# Since only this month is present in both training & test set, we created a flag for this month to include its' importance in the model. We will then drop the month column.
# We have defined a function called september() available in our library my_lib, to compute this feature.

# %%
#Apply lambda function to calculate feature using september() function on month column.
construction_df["Is_Sep"] = construction_df["month"].apply(lambda x: my_lib.september(x))
construction_df = construction_df.drop("month", axis = 1)

# Repeat process for production dataset
production_df_updated["Is_Sep"] = production_df_updated["month"].apply(lambda x: my_lib.september(x))
production_df_updated = production_df_updated.drop("month", axis = 1)

# %% [markdown]
# #### 4.1.2. Team scores:
# We want to include the impact of the popularity of different teams in our model, since we have seen a strong correlation of home team with the attendance.
# We thought of including external information for this purpose, but to not overcomplicate the problem, we decided to build our own scoring using the following methodology:
# - First we calculate the average attendance of each home team, this represents our "home_team_score"
# - We then merge the this dataframe to our original one, to include this score as a new column
# - We repeat this process also to score the opponent team and create the column "opponent_team_score"
# - Let's store the score dataframes to csv, to call it in the model of the production dataset

# %%
columns = ['home_team','opponent']

# Calculate mean attendance and call it score
for score_col in columns:
    mean_df = construction_df[[score_col, 'attend']].groupby(score_col).mean()
    mean_df = mean_df.rename(columns={"attend": "score" })

    # Load to csv for using this dataframe in production dataset
    mean_df.to_csv(score_col + '_scores.csv',index=True)
    
    #Merge dataframe including mean score with construction 
    construction_df = pd.merge(construction_df, 
                         mean_df, 
                         on =score_col, 
                         how ='left')
    #Rename column to differentiate home score & opponent score
    construction_df = construction_df.rename(columns={"score": score_col + "_score" })

# %%
# Import the mean dataframe computed earlier
home_team_scores = pd.read_csv("./home_team_scores.csv")
opponent_scores = pd.read_csv("./opponent_scores.csv")

# %%
# Merge the dataframe including home teams and their average score with production dataset
production_df_updated = pd.merge(production_df_updated, 
                     home_team_scores, 
                     on = 'home_team', 
                     how ='left')

#Rename column to home_team_score
production_df_updated = production_df_updated.rename(columns={"score": 'home_team_score'})

# Merge the dataframe including opponent teams and their average score  with production dataset                                                              
production_df_updated = pd.merge(production_df_updated, 
                     opponent_scores, 
                     on = 'opponent', 
                     how ='left')
#Rename column to opponent_score
production_df_updated = production_df_updated.rename(columns={"score": 'opponent_score' })

# %% [markdown]
# #### 4.1.3. Weekend:
# We will include a column to flag if the day is Friday, Saturday or Sunday. These days have shown higher attendance in our dataset than the weekdays.
# We have defined a function called weekend() available in our library my_lib, to compute this feature.

# %%
#Apply lambda function to calculate feature using weekend() function on day_of_week column.
construction_df['weekend'] = construction_df['day_of_week'].apply(lambda x: my_lib.weekend(x))
production_df_updated['weekend'] = production_df_updated['day_of_week'].apply(lambda x: my_lib.weekend(x))

# %% [markdown]
# #### 4.1.4. Weather:
# We will include a column to aggregate the temperature into three categories:
# - Cold: Temperature is below 60 degrees
# - Moderate: Temperature is between 60 and 90 degrees
# - Hot: Temperature is above 90 degrees
#
# We have defined a function called weather() available in our library my_lib, to compute this feature.

# %%
#Apply lambda function to calculate feature using weather() function on temp column.
construction_df["weather"] = construction_df["temp"].apply(lambda x: my_lib.weather(x))
production_df_updated["weather"] = production_df_updated["temp"].apply(lambda x: my_lib.weather(x))

# %% [markdown]
# <a id='8'></a>
# ### 4.2. Encoding

# %% [markdown]
# - Binary Categorical Columns: We will replace YES/NO with 0/1.
# - Other Categorical Columns: We will apply One-Hot Encoding.

# %%
# Define Categorical columns with YES/NO:
zero_columns = ["cap","shirt","fireworks","bobblehead","hum>average"] 

# replace with 0 or 1
for column in zero_columns:
    construction_df[column] = construction_df[column].replace({'YES': 1 , 'NO': 0})

# Define categorical columns having higher cardinality
dummy_df = construction_df[["opponent","home_team","day_night","day_of_week","skies","weather"]]

# Perform Dummy Encoding
dummy_df_encoded = pd.get_dummies(dummy_df)

# Drop the previous categorical columns from construction_df 
construction_df = construction_df.drop(columns = dummy_df)

# Merge the new dummy dataframe to construction_df
construction_df = pd.merge(
    left=construction_df,
    right=dummy_df_encoded,
    left_index=True,
    right_index=True,
    )

# %%
# replace categorical columns having YES/NO with 0 or 1
for column in zero_columns:
    production_df_updated[column] = production_df_updated[column].replace({'YES': 1 , 'NO': 0})

# Define categorical columns having higher cardinality
dummy_df = production_df_updated[["opponent","home_team","day_night","day_of_week","skies","weather"]]

# Perform Dummy Encoding
dummy_df_encoded = pd.get_dummies(dummy_df)

# Drop the previous categorical columns from construction_df 
production_df_updated = production_df_updated.drop(columns = dummy_df)

# Merge the new dummy dataframe to construction_df
production_df_updated = pd.merge(
    left=production_df_updated,
    right=dummy_df_encoded,
    left_index=True,
    right_index=True,
    )

# %% [markdown]
# <a id='9'></a>
# ### 4.3. Feature Importance

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor

# Define X as our features of the dataset and y as the target variable attendance (attend) 
X = construction_df.drop(["attend"], axis=1) 
y = construction_df["attend"]

# Choose the model we are finally going to use
rnf_model = RandomForestRegressor(n_estimators = 100)
# Fit X and y
rnf_model.fit(X,y)

#to compute feature importance using this model
importance = rnf_model.feature_importances_

# Create dataframe with feature importance
coefs = pd.DataFrame(
   importance,
   columns=['Coefficients'], index=X.columns
)

# Plot features and their importance
coefs.sort_values('Coefficients').plot(kind='barh', figsize=(9, 20))
plt.title('Random Forest model')
plt.axvline(x=0, color='.5')
plt.subplots_adjust(left=.3)

# %% [markdown]
# Our new features are amongst the most important for the target variable attendance, using Random Forest (Our final chosen model).

# %% [markdown]
# <a id='10'></a>
# ## 5. Modelling

# %% [markdown]
# <a id='11'></a>
# ### 5.1. Train Test Split

# %%
# importing feature scaling function
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Define X as our features of the dataset and y as the target variable attendance (attend) 
X = construction_df.drop(["attend"], axis=1)
y = construction_df["attend"]

# Define X_prod as our production features, remove our target variable attendance (attend) 
X_prod = production_df_updated.drop(["attend"], axis=1)

# Perform train test split
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=53)

# %% [markdown]
# <a id='12'></a>
# ### 5.2. Scaling

# %%
# Define scaler
scaler = MinMaxScaler()
scaler.fit(X_train)

# apply feature scaling to all features
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
X_prod = scaler.transform(X_prod)

# %% [markdown]
# <a id='13'></a>
# ### 5.3. Selection

# %%
# Baseline Model Score using Linear Regression
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_percentage_error
from xgboost import XGBModel

# Define model and fit with X_train and y_train
reg_model = LinearRegression()
reg_model.fit(X_train,y_train)

mape_train = mean_absolute_percentage_error(y_train,reg_model.predict(X_train))
mape_test = mean_absolute_percentage_error(y_test,reg_model.predict(X_test))

print("Train MAPE = {:.4} %".format(round(mape_train*100,4)) )
print("Test MAPE = {:.4} %".format(round(mape_test*100,4)) )
# Out:
# Train MAPE = 14.31 %
# Test MAPE = 14.94 %

# %%
# XGBoost Model

# Define model and fit with X_train and y_train
xgb_model = XGBModel()
# Define parameters to test
param_grid = {'n_estimators':[50,100,200], 'max_depth':[None,5,10,15]}

# Perform gridsearch and save model with best parameters as grid_result
grid_search = GridSearchCV(xgb_model, param_grid, scoring="neg_mean_absolute_percentage_error")
grid_result = grid_search.fit(X_train, y_train)

# Print parameters of best performing model
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

# Compute MAPE for train and test set
mape_train = mean_absolute_percentage_error(y_train,grid_result.predict(X_train))
mape_test = mean_absolute_percentage_error(y_test,grid_result.predict(X_test))

# Print score
print("Train MAPE = {:.4} %".format(round(mape_train*100,4)) )
print("Test MAPE = {:.4} %".format(round(mape_test*100,4)) )
# Out:
# Best: -0.131413 using {'max_depth': 5, 'n_estimators': 50}
# Train MAPE = 7.229 %
# Test MAPE = 12.57 %

# %%
# Random Forest Model

# Define model and fit with X_train and y_train
rnf_model = RandomForestRegressor()
# Define parameters to test
param_grid = {'n_estimators':[150,200], 'max_depth':[None,30,45,60]}
grid_search = GridSearchCV(rnf_model, param_grid, scoring="neg_mean_absolute_percentage_error")
grid_result = grid_search.fit(X_train, y_train)

# Perform gridsearch and save model with best parameters as grid_result
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))


# Compute MAPE for train and test set
mape_train = mean_absolute_percentage_error(y_train,grid_result.predict(X_train))
mape_test = mean_absolute_percentage_error(y_test,grid_result.predict(X_test))

# Print score
print("Train MAPE = {:.4} %".format(round(mape_train*100,4)) )
print("Test MAPE = {:.4} %".format(round(mape_test*100,4)) )
# Out:
# Best: -0.132288 using {'max_depth': 60, 'n_estimators': 200}
# Train MAPE = 4.8 %
# Test MAPE = 12.58 %

# %% [markdown]
# The score using RandomForest Regressor is the same as using XGBoost, as we know RandomForest is better suited for overfitting & reducing variance, we select this as the final model.

# %% [markdown]
# <a id='14'></a>
# ## 6. Prediction

# %%
# Predict the targets of our production dataset
prod_pred = grid_result.predict(X_prod)

# %%
# Create dataframe with ID and the predicted attendance using our production dataset
result = production_df[['Unnamed: 0']]
result['attend'] = prod_pred

# Store to csv
result.to_csv('submission.csv',index=False)
# Out:
# /var/folders/yk/yy1ld_kx6477b9gjlvd5_lm80000gn/T/ipykernel_25805/1301694619.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
